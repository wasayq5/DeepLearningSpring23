# %% [markdown]
# <a href="https://colab.research.google.com/github/wasayq5/DeepLearningSpring23/blob/main/Untitled7.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import cv2
# !wget "https://cdn.pixabay.com/photo/2017/06/14/00/59/samoyed-2400687_960_720.jpg"
# Out:
# --2023-02-15 23:08:05--  https://cdn.pixabay.com/photo/2017/06/14/00/59/samoyed-2400687_960_720.jpg
# Resolving cdn.pixabay.com (cdn.pixabay.com)... 104.18.15.16, 104.18.14.16, 2606:4700::6812:e10, ...
# Connecting to cdn.pixabay.com (cdn.pixabay.com)|104.18.15.16|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 183274 (179K) [binary/octet-stream]
# Saving to: ‘samoyed-2400687_960_720.jpg’
#
# samoyed-2400687_960 100%[===================>] 178.98K  --.-KB/s    in 0.03s
#
# 2023-02-15 23:08:06 (6.64 MB/s) - ‘samoyed-2400687_960_720.jpg’ saved [183274/183274]

# %%
samoyed = cv2.imread('samoyed-2400687_960_720.jpg',1)

# %%
from matplotlib import pyplot as plt
plt.imshow(samoyed)
plt.axis("off")
plt.imshow(cv2.cvtColor(samoyed, cv2.COLOR_BGR2RGB))
plt.show()

# %%
samoyed.shape
# Out:
# (720, 720, 3)

# %%
for i in range(30):
  for j in range(30):
    samoyed[i][j] = (0,0,0)

# %%
plt.axis("off")
plt.imshow(cv2.cvtColor(samoyed, cv2.COLOR_BGR2RGB))
plt.show()
